# %%
import numpy as np
from numpy import *
import copy
def R(cube):
  a=cube[1,2:5].copy()
  b=cube[5,2:5].copy()
  c=cube[3,2:5].copy()
  d=cube[4,2:5].copy()
  cube[1,2:5]=b
  cube[5,2:5]=c
  cube[3,2:5]=d
  cube[4,2:5]=a
  p=[""]*8
  for i in range(8):
    p[i]=(cube[0,i]).copy()
  for i in range(8): 
    cube[0,i]=p[i-2]
  
def RA(cube):
  R(cube)
  R(cube)
  R(cube)
  
def U(cube):
  a=cube[0,0:3].copy()
  b=cube[1,0:3].copy()
  c=cube[2,0:3].copy()
  d=cube[3,4:7].copy()
  cube[0,0:3]=d
  cube[1,0:3]=a
  cube[2,0:3]=b
  cube[3,4:7]=c
  p=[""]*8
  for i in range(8):
    p[i]=(cube[4,i]).copy()
  for i in range(8): 
    cube[4,i]=p[i-2]
  
def UA(cube):
  U(cube)
  U(cube)
  U(cube)
  
def F(cube):
  a=cube[2,2:5].copy()
  b=cube[4,4:7].copy()
  c=cube[0,6].copy(),cube[0,7].copy(),cube[0,0].copy()
  d=cube[5,0:3].copy()
  cube[2,2:5]=d
  cube[4,4:7]=a
  cube[0,6],cube[0,7],cube[0,0]=b[0],b[1],b[2]
  cube[5,0:3]=c
  p=[""]*8
  for i in range(8):
    p[i]=(cube[1,i]).copy()
  for i in range(8): 
    cube[1,i]=p[i-2]
  
def FA(cube):
  F(cube)
  F(cube)
  F(cube)
  
def L(cube):
  a=cube[1,6].copy(),cube[1,7].copy(),cube[1,0].copy()
  b=cube[5,6].copy(),cube[5,7].copy(),cube[5,0].copy()
  c=cube[3,6].copy(),cube[3,7].copy(),cube[3,0].copy()
  d=cube[4,6].copy(),cube[4,7].copy(),cube[4,0].copy()
  cube[1,6],cube[1,7],cube[1,0]=d
  cube[5,6],cube[5,7],cube[5,0]=a
  cube[3,6],cube[3,7],cube[3,0]=b
  cube[4,6],cube[4,7],cube[4,0]=c
  p=[""]*8
  for i in range(8):
    p[i]=(cube[2,i]).copy()
  for i in range(8): 
    cube[2,i]=p[i-2]
def LA(cube):
  L(cube)
  L(cube)
  L(cube)
def D(cube):
  a=cube[0,4:7].copy()
  b=cube[1,4:7].copy()
  c=cube[2,4:7].copy()
  d=cube[3,0:3].copy()
  cube[0,4:7]=b
  cube[1,4:7]=c
  cube[2,4:7]=d
  cube[3,0:3]=a
  p=[""]*8
  for i in range(8):
    p[i]=(cube[5,i]).copy()
  for i in range(8): 
    cube[5,i]=p[i-2]
def DA(cube):
  D(cube)
  D(cube)
  D(cube)
def B(cube):
  a=cube[4,0:3].copy()
  b=cube[0,2:5].copy()
  c=cube[5,4:7].copy()
  d=cube[2,6].copy(),cube[2,7].copy(),cube[2,0].copy()
  cube[4,0:3]=b
  cube[0,2:5]=c
  cube[5,4:7]=d
  cube[2,6],cube[2,7],cube[2,0]=a[0],a[1],a[2]
  p=[""]*8
  for i in range(8):
    p[i]=(cube[3,i]).copy()
  for i in range(8): 
    cube[3,i]=p[i-2]
def BA(cube):
  B(cube)
  B(cube)
  B(cube)

def Solve(cube):

  for i in range(1):
    if cube[1][2]=="B":
      R(cube)
      U(cube)
      RA(cube)
      print("R U R' ")
      break
    if cube[1][2]=="O":
      LA(cube)
      U(cube)
      L(cube)
      print("L' U L ")
      break
    if cube[1][2]=="R":
      U(cube)
      U(cube)
      RA(cube)
      U(cube)
      R(cube)
      print("U2 R' U R ")
      break
    if cube[1][2]=="G":
      U(cube)
      U(cube)
      L(cube)
      U(cube)
      LA(cube)
      print("U2 L U L' ")
      break
def SolveU(cube):
  if cube[5][2]=="W" and cube[1][4]=="B":
    R(cube)
    U(cube)
    U(cube)
    RA(cube)
    UA(cube)
    R(cube)
    UA(cube)
    RA(cube)
    U(cube)
    U(cube)
    print("R U2 R' U' R U' R' U2 ")
    Solvef(cube)
    
  else:
    R(cube)
    U(cube)
    U(cube)
    RA(cube)
    UA(cube)
    print("R U2 R' U' ")
    Solve(cube)
def Solvef(cube):
  for i in range(1):
    if cube[0][0]=="R":
      U(cube)
      R(cube)
      UA(cube)
      RA(cube)
      print("U R U' R' ")
      continue
    if cube[0][0]=="B":
      U(cube)
      U(cube)
      F(cube)
      UA(cube)
      FA(cube)
      print("U2 F U' F' ")
      continue
    if cube[0][0]=="O":
      UA(cube)
      L(cube)
      UA(cube)
      LA(cube)
      print("U' L U' L' ")
      continue
    if cube[0][0]=="G":
      B(cube)
      UA(cube)
      BA(cube)
      print("B U' B' U")
      U(cube)
      print(cube)
      continue
def A1perm(cube):
  
  t=cube[4][2].copy()
  cube[4][2]=cube[4][0].copy()
  cube[4][0]=cube[1][0].copy()
  cube[1][0]=t.copy()
  t=cube[0][2].copy()
  cube[0][2]=cube[3][6].copy()
  cube[3][6]=cube[4][6].copy()
  cube[4][6]=t.copy()
  t=cube[3][4].copy()
  cube[3][4]=cube[2][0].copy()
  cube[2][0]=cube[2][2].copy()
  cube[2][2]=t.copy()
  
  t=cube[4][1].copy()
  cube[4][1]=cube[1][3].copy()
  cube[1][3]=cube[1][1].copy()
  cube[1][1]=cube[2][1].copy()
  cube[2][1]=cube[4][3].copy()
  cube[4][3]=t.copy()
  t=cube[3][5].copy()
  cube[3][5]=cube[0][7].copy()
  cube[0][7]=cube[4][5].copy()
  cube[4][5]=cube[4][7].copy()
  cube[4][7]=cube[0][1].copy()
  cube[0][1]=t.copy()
  print("A1 perm")
def A2perm(cube):
  t=cube[4][2].copy()
  cube[4][2]=cube[1][2].copy()
  cube[1][2]=cube[4][0].copy()
  cube[4][0]=t.copy()
  t=cube[0][2].copy()
  cube[0][2]=cube[0][0].copy()
  cube[0][0]=cube[3][6].copy()
  cube[3][6]=t.copy()
  t=cube[3][4].copy()
  cube[3][4]=cube[4][4].copy()
  cube[4][4]=cube[2][0].copy()
  cube[2][0]=t.copy()
  
  t=cube[4][1].copy()
  cube[4][1]=cube[1][7].copy()
  cube[1][7]=cube[1][1].copy()
  cube[1][1]=cube[0][1].copy()
  cube[0][1]=cube[4][7].copy()
  cube[4][7]=t.copy()
  t=cube[3][5].copy()
  cube[3][5]=cube[2][3].copy()
  cube[2][3]=cube[4][5].copy()
  cube[4][5]=cube[4][3].copy()
  cube[4][3]=cube[2][1].copy()
  cube[2][1]=t.copy()
  print("A2 perm")
def E(cube):
  t=cube[0][7].copy()
  cube[0][7]=cube[3][3].copy()
  cube[3][3]=cube[2][7].copy()
  cube[2][7]=cube[1][7].copy()
  cube[1][7]=t.copy()
  t=cube[0][3].copy()
  cube[0][3]=cube[3][7].copy()
  cube[3][7]=cube[2][3].copy()
  cube[2][3]=cube[1][3].copy()
  cube[1][3]=t.copy()
def E2(cube):
  E(cube)
  E(cube)
def EA(cube):
  E(cube)
  E(cube)
  E(cube)
def slayer(cube):
  if cube[1][1]=="B": 
    if cube[4][5]=="R":
      A1perm(cube)
    elif cube[4][5]=="O":
      A2perm(cube)
  if cube[1][1]=="R":
    if cube[4][5]=="B":
      E(cube) 
      print("E")
      A2perm(cube)
      EA(cube) 
      print("E' ")
    elif cube[4][5]=="G":
      EA(cube) 
      print("E' ")    
      A1perm(cube)
      E(cube) 
      print("E")
  if cube[1][1]=="G":
    if cube[4][5]=="O":
      E2(cube) 
      print("E2 ")
      A1perm(cube)
      E2(cube) 
      print("E2 ")
    elif cube[4][5]=="R":
      E2(cube) 
      print("E2 ")
      A2perm(cube)
      E2(cube) 
      print("E2 ")
  if cube[1][1]=="O":
    if cube[4][5]=="B":
      EA(cube) 
      print("E' ")
      A1perm(cube)
      E(cube) 
      print("E")
    elif cube[4][5]=="G":
      EA(cube) 
      print("E'")
      A2perm(cube)
      E(cube) 
      print("E ")
def s2layer(cube):
  for i in range(4):
    if cube[1][1]!="Y" and cube[4][5]!="Y":
      slayer(cube)
      continue
    if cube[0][1]!="Y" and cube[4][3]!="Y":
      U(cube)
      print("U ")
      slayer(cube)
      continue
    if cube[2][1]!="Y" and cube[4][7]!="Y":
      UA(cube)
      print("U' ")
      slayer(cube)
      continue
    if cube[3][5]!="Y" and cube[4][1]!="Y":
      U(cube)
      U(cube)
      print("U2 ")
      slayer(cube)
      continue
def B1perm(cube):
  F(cube)
  R(cube)
  U(cube)
  RA(cube)
  UA(cube)
  FA(cube)
  print("F R U R' U' F'")  
def B2perm(cube):
  F(cube)
  U(cube)
  R(cube)
  UA(cube)
  RA(cube)
  FA(cube)
  print("F U R U' R' F'")
def Tperm(cube):
  a=cube[0][1].copy()
  cube[0][1]=cube[2][1].copy()
  cube[2][1]=a.copy()
  b=cube[0][0].copy()
  cube[0][0]=cube[3][4].copy()
  cube[3][4]=b.copy()
  c=cube[0][2].copy()
  cube[0][2]=cube[1][2].copy()
  cube[1][2]=c.copy()
  print("Tperm")
def U1perm(cube):
  a=cube[0][1].copy()
  cube[0][1]=cube[1][1].copy()
  cube[1][1]=cube[2][1].copy()
  cube[2][1]=a.copy()
  print("U1perm")
def U2perm(cube):
  a=cube[0][1].copy()
  cube[0][1]=cube[2][1].copy()
  cube[2][1]=cube[1][1].copy()
  cube[1][1]=a.copy()
  print("U2perm")
y=[[[5,3],[4,3],[1,3],[3,3]],
   [[5,1],[4,5],[2,3],[0,7]],
   [[5,7],[4,7],[3,7],[1,7]],
   [[4,1],[5,5],[2,7],[0,3]],
   [[1,1],[3,5],[2,1],[0,1]],
   [[3,1],[1,5],[2,5],[0,5]]]
  
cube=array([["Y", "B", "W", "W", "W", "B", "R", "O"],
            ["G", "W", "B", "G", "Y", "O", "W", "G"],
            ['O', 'O', 'R', 'Y', 'B', 'W', 'W', 'O'],
            ['R', 'G', 'G', 'G', 'G', 'R', 'G', 'B'],
            ['Y', 'Y', 'R', 'R', 'O', 'B', 'Y', 'W'],
            ['O', 'Y', 'B', 'Y', 'O', 'R', 'B', 'R']])

x=[]
for i in range(6):
  for j in range(8):
    if cube[i][j]=="W" and j%2!=0:
      x.append([i, j])

for i in range (4):

  h=y[x[i][0]][(x[i][1])%5][0]
  p=y[x[i][0]][x[i][1]%5][1]
  if cube[h][p]=="B":
    temp=x[i]
print(temp)
if temp[0]==0:
  if temp[1]==1:
    RA(cube)
    F(cube)
    print("R' F ")
  if temp[1]==3:
    R(cube)
    R(cube)
    F(cube)
    print("R2 F ")
  if temp[1]==5:
    R(cube)
    F(cube)
    print("R F ")
  if temp[1]==7:
    F(cube)
    print("F ")

if temp[0]==1:
  if temp[1]==1:
    F(cube)
    R(cube)
    U(cube)
    F(cube)
    F(cube)
    print("F R U F2 ")
  
  if temp[1]==3:
    R(cube)
    U(cube)
    F(cube)
    F(cube)
    print("R U F2 ")
  if temp[1]==5:
    FA(cube)
    RA(cube)
    D(cube)
    D(cube)
    D(cube)
    print("F' R' D' ")
  if temp[1]==7:
    L(cube)
    D(cube)
    print("L D ")

if temp[0]==2:
  if temp[1]==1:
    L(cube)
    print("L F' ")
    FA
    print(cube)
  if temp[1]==3:
    FA(cube)
    print("F' ")
  if temp[1]==5:
    LA(cube)
    FA(cube)
    print("L' F' ")
  if temp[1]==7:
    L(cube)
    L(cube)
    print("L L F' ")
    FA(cube)
if temp[0]==3:
  if temp[1]==1:
    B(cube)
    print("B R' U F2 ")
    RA(cube)
    U(cube)
    F(cube)
    F(cube)
  
  if temp[1]==3:
    RA(cube)
    U(cube)
    F(cube)
    F(cube)
    print("R' U F2 ")
  if temp[1]==5:
    B(cube)
    B(cube)
    B(cube)
    print("B' R' U F2 ")
    RA(cube)
    U(cube)
    F(cube)
    F(cube)
  if temp[1]==7:
    L(cube)
    print("L U' F2 ")
    UA(cube)
    F(cube)
    F(cube)
if temp[0]==4:
  if temp[1]==1:

    U(cube)
    U(cube)
    F(cube)
    F(cube)
    print('U2 F2 ')
  if temp[1]==3:
    U(cube)
    F(cube)
    F(cube)
    print('U F2 ')
  if temp[1]==5:
    F(cube)
    F(cube)
    print('F2 ')
  if temp[1]==7:
    UA(cube)
    F(cube)
    print("U' F ")

if temp[0]==5:
  if temp[1]==3:
    D(cube)
    D(cube)
    D(cube)
    print("D' ")
  if temp[1]==5:
    D(cube)
    D(cube)
    print("D D ")
  if temp[1]==7:
    D(cube)
    print("D ")



x=[]
for i in range(6):
  for j in range(8):
    if cube[i,j]=="W" and j%2!=0:
      x.append([i, j])
for i in range (4):

  h=y[x[i][0]][(x[i][1])%5][0]
  p=y[x[i][0]][x[i][1]%5][1]
  if cube[h][p]=="R":
    temp=x[i]



if temp[0]==0:
  if temp[1]==1:
    D(cube)
    D(cube)
    D(cube)
    RA(cube)
    F(cube)
    D(cube)
    print("D' R' F D ")
  if temp[1]==3:
    D(cube)
    B(cube)
    B(cube)
    B(cube)
    DA(cube)
    print("D B' D' ")
  if temp[1]==5:
    R(cube)
    DA(cube)
    F(cube)
    D(cube)
    print("R D' F D ")
  if temp[1]==7:
    DA(cube)
    F(cube)
    D(cube)
    print("D' F D ")

if temp[0]==1:
  if temp[1]==1:
    F(cube)
    RA(cube)
    FA(cube)
    print("F R' F' ")
  
  if temp[1]==3:
    RA(cube)
    print("R' ")
 
  if temp[1]==7:
    LA(cube)
    U(cube)
    U(cube)
    R(cube)
    R(cube)
    print("L' U2 R2 ")

if temp[0]==2:
  if temp[1]==1:
    UA(cube)
    F(cube)
    RA(cube)
    FA(cube)
    print("U' F R' F' ")
    
  if temp[1]==3:
    DA(cube)
    FA(cube)
    D(cube)
    print("D' F' D ")
  if temp[1]==5:
    LA(cube)
    DA(cube)
    FA(cube)
    D(cube)
    print("L' D' F' D ")
  if temp[1]==7:
    BA(cube)
    U(cube)
    R(cube)
    R(cube)
    print("B' U R2 ")
    
if temp[0]==3:
  if temp[1]==1:
    B(cube)
    print("B R ")
    R(cube)
    
  if temp[1]==3:
    R(cube)
    print("R ")
  if temp[1]==5:
    B(cube)
    B(cube)
    B(cube)
    R(cube)
    print("B' R ")
    
  if temp[1]==7:
    B(cube)
    B(cube)
    R(cube)
    print("B2 R ")
if temp[0]==4:
  if temp[1]==1:
    U(cube)
    R(cube)
    R(cube)
    print("U R2 ")
  if temp[1]==3:
    R(cube)
    R(cube)
    print("R2 ")
  if temp[1]==5:
    UA(cube)
    R(cube)
    R(cube)
    print("U' R2 ")
    
  if temp[1]==7:
    U(cube)
    U(cube)
    R(cube)
    R(cube)
    print("U2 R2 ")

if temp[0]==5:
  
  if temp[1]==5:
    F(cube)
    DA(cube)
    FA(cube)
    print("F D' F' ")
  if temp[1]==7:
    L(cube)
    L(cube)
    U(cube)
    U(cube)
    R(cube)
    R(cube)
    print("L2 U2 R2 ")
    
x=[]
for i in range(6):
  for j in range(8):
    if cube[i,j]=="W" and j%2!=0:
      x.append([i, j])
for i in range (4):

  h=y[x[i][0]][(x[i][1])%5][0]
  p=y[x[i][0]][x[i][1]%5][1]
  if cube[h][p]=="O":
    temp=x[i]
if temp[0]==0:
  if temp[1]==3:
    B(cube)
    UA(cube)
    L(cube)
    L(cube)
    print("B U' L2 ")
  if temp[1]==1:
    UA(cube)
    FA(cube)
    L(cube)
    F(cube)
    print("U' F' L F ")
if temp[0]==1:
  if temp[1]==1:
    FA(cube)
    L(cube)
    F(cube)
    print("F' L F ")
  if temp[1]==3:
    R(cube)
    U(cube)
    U(cube)
    L(cube)
    L(cube)
    RA(cube)
    print("R U2 L2 R' ")
  if temp[1]==7:
    L(cube)
    print("L ")
if temp[0]==2:
  if temp[1]==1:
    L(cube)
    F(cube)
    U(cube)
    FA(cube)
    L(cube)
    L(cube)
    print("L F U F' L2 ")
  if temp[1]==3:
    F(cube)
    U(cube)
    FA(cube)
    L(cube)
    L(cube)
    print("F U F' L2 ")
  if temp[1]==5:
    LA(cube)
    F(cube)
    U(cube)
    FA(cube)
    L(cube)
    L(cube)
    print("L' F U F' L2 ")
  if temp[1]==7:
    BA(cube)
    UA(cube)
    L(cube)
    L(cube)
    print("B' U' L2 ")
if temp[0]==3:
  if temp[1]==1:
    BA(cube)
    LA(cube)
    print("B' L' ")
  if temp[1]==3:
    B(cube)
    B(cube)
    LA(cube)
    print("B2 L' ")
  if temp[1]==5:
    B(cube)
    LA(cube)
    print("B L' ")
  if temp[1]==7:
    LA(cube)
    print("L' ")
if temp[0]==4:
  if temp[1]==1:
    UA(cube)
    L(cube)
    L(cube)
    print("U' L2 ")
  if temp[1]==3:
    U(cube)
    U(cube)
    L(cube)
    L(cube)
    print("U2 L2 ")
  if temp[1]==5:
    U(cube)
    
    L(cube)
    L(cube)
    print("U L2 ")
  if temp[1]==7:
    
    L(cube)
    L(cube)
    print("L2 ")
if temp[0]==5 and temp[1]==5:
  B(cube)
  B(cube)
  UA(cube)
  L(cube)
  L(cube)
  print("B2 U' L2 ")

x=[]
for i in range(6):
  for j in range(8):
    if cube[i,j]=="W" and j%2!=0:
      x.append([i, j])
for i in range (4):

  h=y[x[i][0]][(x[i][1])%5][0]
  p=y[x[i][0]][x[i][1]%5][1]
  if cube[h][p]=="G":
    temp=x[i]
if temp[0]==0:
  if temp[1]==1:
    R(cube)
    BA(cube)
    RA(cube)
    print("R B' R'")
  if temp[1]==3:
    BA(cube)
    print("B' ")
  if temp[1]==7:
    R(cube)
    R(cube)
    BA(cube)
    R(cube)
    R(cube)
    print("R2 B' R2")

if temp[0]==1:
  if temp[1]==1:
    UA(cube)
    R(cube)
    BA(cube)
    RA(cube)
    print("U' R B' R'")
  if temp[1]==3:
    R(cube)
    UA(cube)
    RA(cube)
    B(cube)
    B(cube)
    print("R U' R' B2 ")

  if temp[1]==7:
    LA(cube)
    U(cube)
    L(cube)
    B(cube)
    B(cube)
    print("L' U L B2 ")

if temp[0]==2:
  if temp[1]==1:
    LA(cube)
    B(cube)
    L(cube)
    print("L' B L ")

  if temp[1]==3:
    L(cube)
    L(cube)
    B(cube)
    L(cube)
    L(cube)
    print("L2 B L2 ")
  if temp[1]==7:
    B(cube)
    print("B ")
if temp[0]==3:
  if temp[1]==1:
    B(cube)
    L(cube)
    U(cube)
    LA(cube)
    B(cube)
    B(cube)
    print("B L U L' B2 ")
  if temp[1]==3:
    DA(cube)
    R(cube)
    D(cube)
    print("D' R D ")
  if temp[1]==5:
    BA(cube)
    DA(cube)
    R(cube)
    D(cube)
    print("B' D' R D ")
  if temp[1]==7:
    D(cube)
    LA(cube)
    DA(cube)
    print("D L' D' ")
if temp[0]==4:
  if temp[1]==1:
    B(cube)
    B(cube)
    print("B2")

  if temp[1]==3:
    UA(cube)
    B(cube)
    B(cube)
    print("U' B2")
  if temp[1]==7:
    U(cube)
    B(cube)
    B(cube)
    print("U B2 ")
  if temp[1]==5:
    U(cube)
    U(cube)
    B(cube)
    B(cube)
    print("U2 B2 ")
print(cube)
s=5
if cube[5][0]=="W" and cube[0][4]=="B":
  s=s-1
if cube[5][2]=="W" and cube[1][4]=="B":
  s=s-1
if cube[5][6]=="W" and cube[2][6]=="O":
  s=s-1
if cube[5][4]=="W" and cube[0][4]=="R":
  s=s-1
print(s)
for i in range(s):
  
  if cube[0][0]=="W":
    Solve(cube)
    continue
  if cube[3][4]=="W":
    U(cube)
    print("U ")
    Solve(cube)
    continue
  if cube[2][0]=="W":
    U(cube)
    U(cube)
    print("U2 ")
    Solve(cube)
    continue
  if cube[1][0]=="W":
    UA(cube)
    print("U' ")
    Solve(cube)
    continue
  if cube[4][0]=="W":
    U(cube)
    U(cube)
    print("U2 ")
    SolveU(cube)
    continue
  if cube[4][2]=="W":
    U(cube)
    print("U ")
    SolveU(cube)
    continue
  if cube[4][4]=="W":
    SolveU(cube)
    continue
  if cube[4][6]=="W":
    UA(cube)
    print("U' ")
    SolveU(cube)
    continue
  if cube[1][2]=="W":
    Solvef(cube)
    continue
  if cube[0][2]=="W":
    U(cube)
    print("U ")
    Solvef(cube)
    continue
  if cube[3][6]=="W":
    U(cube)
    U(cube)
    print("U2 ")
    continue
    Solvef(cube)
  if cube[2][2]=="W":
    UA(cube)
    Solvef(cube)
    continue
  if cube[0][6]=="W":
    R(cube)
    U(cube)
    RA(cube)
    UA(cube)
    print("R U R' U' ")
    Solve(cube)
    continue
  if cube[1][4]=="W" :
    R(cube)
    UA(cube)
    RA(cube)
    print("R U' R' ")
    Solvef(cube)
    continue
  
  if cube[5][2]=="W" and cube[1][4]!="B":
    R(cube)
    UA(cube)
    RA(cube)
    print("R U' R' ") 
    Solve(cube)
    continue
  if cube[0][4]=="W":
    B(cube)
    UA(cube)
    BA(cube)
    U(cube)
    print("B U' B' U ")
    
    Solvef(cube)
    
    continue
  if cube[3][2]=="W":
    B(cube)
    U(cube)
    BA(cube)
    print("B U B' ")
    Solve(cube)
    continue
  
    
  if cube[5][4]=="W" and cube[0][4]!="R":
    B(cube)
    U(cube)
    BA(cube)
    print("B U B' ")
    Solvef(cube)
    continue
  if cube[1][6]=="W":
    LA(cube)
    U(cube)
    L(cube)
    UA(cube)
    print("L' U L U' ")
    Solve(cube)
    continue
  if cube[2][4]=="W":
    F(cube)
    UA(cube)
    FA(cube)
    UA(cube)
    print("F U' F' U' ")
    Solvef(cube)
    continue

  if cube[5][0]=="W" and cube[1][6]!="B":
    LA(cube)
    UA(cube)
    L(cube)
    print("L' U' L ")
    continue
  if cube[2][6]=="W":
    L(cube)
    U(cube)
    LA(cube)
    U(cube)
    print("L U L' U ")
    Solve(cube)
    continue
  if cube[3][0]=="W":
    BA(cube)
    UA(cube)
    B(cube)
    UA(cube)
    print("B' U' B U' ")
    Solvef(cube)
    continue
  if cube[5][6]=="W" and cube[2][6]!="B":
    BA(cube)
    UA(cube)
    B(cube)
    UA(cube)
    print("B' U' B U' ")
    Solve(cube)
    continue
s2layer(cube)
if cube[0][3]!="R" or cube[3][3]!="G":
  E(cube)
  print("E")
  A1perm(cube)
  U(cube)
  U(cube)
  print("U2")
  EA(cube)
  print("E'")
  slayer(cube)
  s2layer(cube)
if cube[0][7]!="R" or cube[1][3]!="B":
  A1perm(cube)
  U(cube)
  U(cube)
  print("U2")
  slayer(cube)
  s2layer(cube)
if cube[1][7]!="B" or cube[2][3]!="O":
  A2perm(cube)
  U(cube)
  U(cube)
  print("U2")
  slayer(cube)
  s2layer(cube)
if cube[3][7]!="G" or cube[2][7]!="O":
  EA(cube)
  print("E'")
  A2perm(cube)
  E(cube)
  print("E")
  U(cube)
  U(cube)
  print("U2")
  slayer(cube)
  s2layer(cube)

w=0
for i in range(4):
  if cube[4][2*i+1]=="Y":
    w=w+1
if w==2:
  if cube[4][1]=="Y":
    if cube[4][5]=="Y":
      U(cube)
      print("U ")
      B1perm(cube)
    if cube[4][3]=="Y":
      UA(cube)
      print("U'")
      B2perm(cube)
    if cube[4][7]=="Y":
      B2perm(cube)
  elif cube[4][3]=="Y":
    if cube[4][7]=="Y":
      B1perm(cube)
    if cube[4][5]=="Y":
      U(cube)
      U(cube)
      print("U2")
      B2perm(cube)
  else:
    U(cube)
    print("U")
    B2perm(cube)
elif w==0:
  B2perm(cube)
  UA(cube)
  print("U'")
  B1perm(cube)

if cube[4][0]!="Y" and cube[4][2]!="Y" and cube[4][4]!="Y" and cube[4][6]!="Y":
  if cube[0][0]=="Y" and cube[0][2]=="Y" and cube[2][0]=="Y" and cube[2][2]=="Y":
    R(cube)
    U(cube)
    RA(cube)
    U(cube)
    R(cube)
    UA(cube)
    R(cube) 
    U(cube) 
    R(cube) 
    U(cube)
    U(cube)
    R(cube)
    print("R U R' U R U' R' U R U2 R' ")
  elif cube[1][0]=="Y" and cube[1][2]=="Y" and cube[3][4]=="Y" and cube[3][6]=="Y":
    U(cube)
    R(cube)
    U(cube)
    RA(cube)
    U(cube)
    R(cube)
    UA(cube)
    R(cube) 
    U(cube) 
    R(cube) 
    U(cube)
    U(cube)
    R(cube)
    print("U R U R' U R U' R' U R U2 R' ")

q=0
for i in range(4):
  if cube[4][2*i]=="Y":
    q=q+1
    y=i
print(q)
if q==1:
  if y==0:
    U(cube)
    U(cube)
    print("U2")
    if cube[0][0]=="Y":
      U(cube)
      RA(cube)
      UA(cube)
      R(cube)
      UA(cube)
      RA(cube)
      U(cube)
      U(cube)
      R(cube)
      print("U R' U' R U' R' U2 R")
    else:
      R(cube)
      U(cube)
      RA(cube)
      U(cube)
      R(cube)
      U(cube)
      U(cube)
      RA(cube)
      print("R U R' U R U2 R'")
if q==2:
  if cube[0][0]=="Y" and cube[0][2]=="Y":
    U(cube)
    R(cube)
    R(cube)
    D(cube)
    RA(cube)
    U(cube)
    R(cube) 
    DA(cube)
    RA(cube)
    U(cube)
    RA(cube)
    print("U R2 D R' U R D' R' U R'")
  elif cube[1][0]=="Y" and cube[1][2]=="Y":
    R(cube)
    R(cube)
    D(cube)
    RA(cube)
    U(cube)
    R(cube) 
    DA(cube)
    RA(cube)
    U(cube)
    RA(cube)
    print("R2 D R' U R D' R' U R'")
  elif cube[2][0]=="Y" and cube[2][2]=="Y":
    UA(cube)
    R(cube)
    R(cube)
    D(cube)
    RA(cube)
    U(cube)
    R(cube) 
    DA(cube)
    RA(cube)
    U(cube)
    RA(cube)
    print("U' R2 D R' U R D' R' U R'")
  elif cube[3][4]=="Y" and cube[3][6]=="Y":
    U(cube)
    U(cube)
    R(cube)
    R(cube)
    D(cube)
    RA(cube)
    U(cube)
    R(cube) 
    DA(cube)
    RA(cube)
    U(cube)
    RA(cube)
    print("U2 R2 D R' U R D' R' U R'")
RA(cube)
F(cube)
R(cube)
BA(cube)
RA(cube)
FA(cube)
R(cube)
B(cube)
w=0
if cube[0][0]==cube[0][2]:
  w=w+1
  q=1
if cube[1][0]==cube[1][2]:
  w=w+1
  q=2
if cube[2][0]==cube[2][2]:
  w=w+1
  q=3
if cube[3][4]==cube[3][6]:
  w=w+1
  q=4
if w==1:
  if q==1:
    U(cube)
    U(cube)
    print("U2")
    Tperm(cube)
  elif q==2:
    print("U")
    U(cube)
    Tperm(cube)
  elif q==3:
    Tperm(cube)
  elif q==4:
    UA(cube)
    print("U'")
    Tperm(cube)
elif w==0:
  Tperm(cube)
  U(cube)
  U(cube)
  print("U2")
  Tperm(cube)
w=0
if cube[0][0]==cube[0][1]:
  w=w+1
  q=1
if cube[1][0]==cube[1][1]:
  w=w+1
  q=2
if cube[2][0]==cube[1][1]:
  w=w+1
  q=3
if cube[3][3]==cube[3][4]:
  w=w+1
  q=4
if w==1:
  if q==1 and cube[1][1]==cube[3][4]:
    UA(cube)
    print("U'")
    U1perm(cube)
  elif q==1 and cube[1][1]==cube[2][0]:
    UA(cube)
    print("U'")
    U2perm(cube)
  elif q==2 and cube[2][1]==cube[0][1]:
    U(cube)
    U(cube)
    print("U2")
    U1perm(cube)
  elif q==2 and cube[2][1]==cube[3][4]:
    U(cube)
    U(cube)
    print("U2")
    U2perm(cube)
  elif q==3 and cube[1][1]==cube[0][0]:
    U(cube)
    print("U")
    U1perm(cube)
  elif q==3:
    U(cube)
    print("U")
    U2perm(cube)
  elif q==4 and cube[1][1]==cube[0][0]:
    U1perm(cube)
  else:
    U2perm(cube)
if w==0:
  if cube[1][1]==cube[3][4]:
    U1perm(cube)
    U(cube)
    print("U")
    U1perm(cube)
  elif cube[1][1]==cube[0][0]:
    U1perm(cube)
    UA(cube)
    print("U'")
    U1perm(cube)
  else:
    U1perm(cube)
    U(cube)
    U(cube)
    print("U2")
    U2perm(cube)
# Out:
# [1, 1]
# F R U F2
# L' D' F' D
# U' L2
# R U' R' B2
# [['R' 'O' 'G' 'O' 'B' 'R' 'B' 'B']
#  ['W' 'O' 'Y' 'Y' 'O' 'B' 'G' 'Y']
#  ['Y' 'R' 'B' 'G' 'O' 'O' 'W' 'B']
#  ['G' 'G' 'Y' 'G' 'W' 'G' 'B' 'R']
#  ['O' 'R' 'O' 'Y' 'G' 'B' 'R' 'Y']
#  ['Y' 'W' 'W' 'W' 'R' 'W' 'R' 'W']]
# 5
# U
# U2 L U L'
# U
# U2 R' U R
# U2
# R U2 R' U'
# R U R'
# U2
# U2 F U' F'
# E'
# A1 perm
# E
# A1 perm
# U'
# E2
# A1 perm
# E2
# E2
# A2 perm
# E2
# 2
# U
# Tperm
# U2perm

# %%
a=2
b=3
c=a/b
round(c, 2)
c
# Out:
# 0.6666666666666666

# %% [markdown]
# position=np.array([[[0,1],[4,3]],[[0,3],[3,3]],[[0,5],[5,3]],[[0,7],[1,3]],[[1,1][4,5]],[[1,5],[5,1]],[[2,1],[4,7]],[[2,3],[1,7]],[[2,5],[5,7]],[[2,7],[3,7]],[[4,1],[3,5]],[[4,1],[5,5]]])

# %% [markdown]
# c[y[x[2][0]][x[2][1]][0][y[x[2][0]][x[2][1]][1]]
